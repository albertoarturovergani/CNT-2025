# %% [markdown]
# # Balanced network of excitatory and inhibitory neurons.
#
# An implementation of benchmarks from Brette et al. (2007) Journal of Computational Neuroscience 23: 349-398
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/ (see Fig. 24).
#
# In the paper, they compared simulations from NEST and NEURON. Here, we are going to simulate the balanced network with SpiNNaker.
#
# The network is based on the COBA models of Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/ .
#
# You can look also the explicit model in the supplementary material of Brette et al. (2007) |https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2638500/#APP2

# %% [markdown]
# <img src="../../extra/VA_EXC_SPIKES.png">

# %%
pwd
# Out:
# '/home/jovyan/CNT-2025/notebooks/intro'

# %% [markdown]
# # use spinnaker and brain

# %%
# %matplotlib inline   ← solo se sei in Jupyter

# PyNN backend: preferisce SpiNNaker, fallback su Brian2 (if you want to run in Brian2 use scripts/VA/VA_benchmark.py)
try:
    import pyNN.spiNNaker as sim
except ModuleNotFoundError:
    import pyNN.brian2 as sim

from pyNN import space
import numpy as np
import matplotlib.pyplot as plt
import pickle
import time
import datetime
import json
import warnings
from fooof import FOOOF
from scipy.signal import welch
from matplotlib import colors
import os
import datetime

import python_utils as pu

warnings.filterwarnings('ignore')

fileName = 'VA_balance-network'
savePath = '../outputs/'  # Assicurati che esista o usa os.makedirs()
dt_string = datetime.datetime.today().strftime('%Y%m%d_%H%M%S')  # formato sicuro per filesystem
tag = dt_string
saveName = f'{savePath}{fileName}-{tag}'
os.makedirs(saveName, exist_ok=True)
print(f'Saving in: {saveName}')

PARS = {}
# Out:
# /tmp/ipykernel_3900706/3786258914.py:17: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF
# Saving in: ../outputs/VA_balance-network-20251215_091452

# %% [markdown]
# # step0: import the simulator

# %%
import socket
try:
    import pyNN.spiNNaker as sim
except ModuleNotFoundError:
    import pyNN.brian2 as sim
    
from pyNN.random import NumpyRNG, RandomDistribution
from pyNN.utility.plotting import Figure, Panel
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import time
from pyNN import space

# %% [markdown]
# # step1: setup the simulator

# %%
dt = 1          # (ms) simulation timestep
tstop = 1000      # (ms) simulaton duration
delay = 2 # (ms) 

sim.setup(
    timestep=dt, 
    min_delay=delay, 
    max_delay=delay) # [ms] # not that the max_delay supported by SpiNNaker is timestep * 144

rngseed = 98766987
rng = NumpyRNG(seed=rngseed, parallel_safe=True)
# Out:
# max_delay is not supported by sPyNNaker so will be ignored
# 2025-12-15 09:14:52 INFO: Read configs files: /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_utilities/spinn_utilities.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_machine/spinn_machine.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/pacman/pacman.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinnman/spinnman.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# 2025-12-15 09:14:52 INFO: As mode is Production running all reports and keeping files is turned off unless specifically asked for in cfg
# 2025-12-15 09:14:52 INFO: Will search these locations for binaries: /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spynnaker/pyNN/model_binaries
# 2025-12-15 09:14:52 WARNING: /home/jovyan/CNT-2025/notebooks/intro/reports has 21 old reports that have not been closed
# 2025-12-15 09:14:52 INFO: Setting hardware timestep as 1000 microseconds based on simulation time step of 1000 and timescale factor of 1.0

# %% [markdown]
# # step2: decide the cell types and parameters

# %%
# cell type
celltype = sim.IF_cond_exp
#  Leaky integrate and fire model with fixed threshold and exponentially-decaying post-synaptic conductance.
#  http://neuralensemble.org/docs/PyNN/_modules/pyNN/standardmodels/cells.html#IF_cond_exp
    
# Cell parameters
area = 20000.     # (µm²)
tau_m = 20.       # (ms)
cm = 1.           # (µF/cm²)
g_leak = 5e-5     # (S/cm²)

E_leak = None
E_leak = -60.  # (mV)
v_thresh = -50.   # (mV)
v_reset = -60.    # (mV)
t_refrac = 5.     # (ms) (clamped at v_reset)
v_mean = -60.     # (mV) mean membrane potential, for calculating CUBA weights
tau_exc = 5.      # (ms)
tau_inh = 10.     # (ms)
Erev_exc = 0.     # (mV)
Erev_inh = -80.   # (mV)

# === Calculate derived parameters ===
area = area * 1e-8                     # convert to cm²
cm = cm * area * 1000                  # convert to nF
Rm = 1e-6 / (g_leak * area)            # membrane resistance in MΩ
assert tau_m == cm * Rm                # just to check

cell_params = {'tau_m': tau_m,
               'tau_syn_E': tau_exc,
               'tau_syn_I': tau_inh,
               'v_rest': E_leak,
               'v_reset': v_reset,
               'v_thresh': v_thresh,
               'cm': cm,
               'tau_refrac': t_refrac,
               'i_offset': 0
               }

cell_params['e_rev_E'] = Erev_exc
cell_params['e_rev_I'] = Erev_inh

print(cell_params)
# Out:
# {'tau_m': 20.0, 'tau_syn_E': 5.0, 'tau_syn_I': 10.0, 'v_rest': -60.0, 'v_reset': -60.0, 'v_thresh': -50.0, 'cm': 0.2, 'tau_refrac': 5.0, 'i_offset': 0, 'e_rev_E': 0.0, 'e_rev_I': -80.0}

# %% [markdown]
# # step3: making cell populations

# %%
n = 1500       # number of cells
r_ei = 4.0        # number of excitatory cells:number of inhibitory cells
n_exc = int(round((n * r_ei / (1 + r_ei))))  # number of excitatory cells
n_inh = n - n_exc                            # number of inhibitory cells
print("{} {}".format(n_exc, n_inh))

pops = {
    'exc': sim.Population(
                                n_exc, 
                                celltype(**cell_params), 
                                label="Excitatory_Cells"),

    'inh': sim.Population(
                                n_inh, 
                                celltype(**cell_params), 
                                label="Inhibitory_Cells")
}

pops['exc'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])
pops['inh'].record(["spikes", 'v', 'gsyn_exc', 'gsyn_inh'])


uniformDistr = RandomDistribution('uniform', [v_reset, v_thresh])#, rng=rng)
pops['exc'].initialize(v=uniformDistr)
pops['inh'].initialize(v=uniformDistr)

#sim.set_number_of_neurons_per_core(sim.IF_cond_exp, 50)      # this will set
# 50 neurons per core
pops.keys()
# Out:
# 1200 300
# dict_keys(['exc', 'inh'])

# %% [markdown]
# # step4: define the synapse types

# %%
# Synapse parameters
Gexc = None
Ginh = None
Gexc = 4.     # (nS) #1
Ginh = 51. #* 0.15    # (nS) #1
w_exc = Gexc * 1e-3              # We convert conductances to uS
w_inh = Ginh * 1e-3

exc_synapses = sim.StaticSynapse(weight=w_exc, delay=delay)
inh_synapses = sim.StaticSynapse(weight=w_inh, delay=delay)

# %% [markdown]
# # step5: select the connections algorithm

# %%
pconn = 0.02      # connection probability (2%)

exc_conn = sim.FixedProbabilityConnector(pconn)#, rng=rng)
inh_conn = sim.FixedProbabilityConnector(pconn)#, rng=rng)

# %% [markdown]
# # step6: make the projections

# %%
connections = {
    
    'e2e': sim.Projection(
        pops['exc'],
        pops['exc'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'e2i': sim.Projection(
        pops['exc'], 
        pops['inh'], 
        exc_conn, 
        receptor_type='excitatory',
        synapse_type=exc_synapses),
    
    'i2e': sim.Projection(
        pops['inh'], 
        pops['exc'], 
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses),
    
    'i2i': sim.Projection(
        pops['inh'],
        pops['inh'],
        inh_conn, 
        receptor_type='inhibitory',
        synapse_type=inh_synapses)
    
        }

connections.keys()
# Out:
# dict_keys(['e2e', 'e2i', 'i2e', 'i2i'])

# %% [markdown]
# # step7: setting the thalamic stimulus

# %%
n_thalamic_cells = 20 
stim_dur = 50.    # (ms) duration of random stimulation
rate = 100.       # (Hz) frequency of the random stimulation

exc_conn = None

pops['thalamus'] = sim.Population(
    n_thalamic_cells, 
    sim.SpikeSourcePoisson(rate=rate, duration=stim_dur),
    label="expoisson")
pops['thalamus'].record("spikes")


rconn = 0.01
ext_conn = sim.FixedProbabilityConnector(rconn)

connections['ext2e'] = sim.Projection(
    pops['thalamus'], 
    pops['exc'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections['ext2i'] = sim.Projection(
    pops['thalamus'], 
    pops['inh'], 
    ext_conn, 
    receptor_type='excitatory',
    synapse_type=sim.StaticSynapse(weight=0.1))

connections.keys(), pops.keys()
# Out:
# (dict_keys(['e2e', 'e2i', 'i2e', 'i2i', 'ext2e', 'ext2i']),
#  dict_keys(['exc', 'inh', 'thalamus']))

# %% [markdown]
# # step8: run simulation

# %%
tstop = 1000 # (ms)
# simulation run

tic = time.time()
sim.run(tstop)
toc = time.time() - tic
# Out:
# 2025-12-15 09:14:52 INFO: Starting execution process
# 2025-12-15 09:14:52 INFO: Simulating for 1000 1.0 ms timesteps using a hardware timestep of 1000 us
# openjdk version "17.0.16" 2025-07-15
# OpenJDK Runtime Environment (build 17.0.16+8-Ubuntu-0ubuntu124.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.16+8-Ubuntu-0ubuntu124.04.1, mixed mode, sharing)
# 2025-12-15 09:14:52 INFO: SpYNNakerNeuronGraphNetworkSpecificationReport skipped as cfg Reports:write_network_graph is False
# 2025-12-15 09:14:52 INFO: Network Specification report skipped as cfg Reports:write_network_specification_report is False
# 2025-12-15 09:14:52 INFO: Splitter reset took 0:00:00.000017
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:14:52 INFO: Spynnaker splitter selector took 0:00:00.003992
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:14:52 INFO: DelaySupportAdder took 0:00:00.005902
# Partitioning Graph
# |0%                          50%                         100%|
#  2025-12-15 09:14:52 WARNING: The cfg has no version. This is deprecated! Please add a version
# ============================================================
# 2025-12-15 09:14:52 INFO: Splitter partitioner took 0:00:00.010910
# 2025-12-15 09:14:52 INFO: 0.02 Boards Required for 1 chips
# 2025-12-15 09:14:52 INFO: Requesting job with 1 boards
# Created spalloc job 43547
# 2025-12-15 09:14:52 INFO: Created spalloc job 43547
# Job has been queued by the spalloc server.
# 2025-12-15 09:14:52 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2025-12-15 09:14:57 INFO: Waiting for board power commands to complete.
# 2025-12-15 09:15:06 INFO: Creating transceiver for 10.11.233.9
# 2025-12-15 09:15:06 INFO: Working out if machine is booted
# 2025-12-15 09:15:10 INFO: Attempting to boot machine
# 2025-12-15 09:15:18 INFO: Found board with version [Version: SC&MP 4.0.0 at SpiNNaker:0:0:0 (built Fri Nov 17 09:35:48 2023)]
# 2025-12-15 09:15:18 INFO: Machine communication successful
# 2025-12-15 09:15:18 INFO: 10.11.233.9
# 2025-12-15 09:15:18 INFO: Transceiver by Spalloc Old took 0:00:25.905058
# Reading details from 43 chips
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Detected Machine on 10.11.233.9 with 43 Chips, 764 cores and 99.0 links. Chips have sdram of 123469792 bytes, router table of size 1023, between 17 and 18 cores and between 1 and 6 links.
# 2025-12-15 09:15:18 INFO: Json machine skipped as cfg Reports:write_json_machine is False
# 2025-12-15 09:15:18 INFO: Board chip report skipped as cfg Reports:write_board_chip_report is False
# Adding commands
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Command Sender Adder took 0:00:00.003705
# 2025-12-15 09:15:18 INFO: Split Live Gather Vertices took 0:00:00.000009
# 2025-12-15 09:15:18 INFO: Insert chip power monitors skipped as cfg Reports:write_energy_report is False
# 2025-12-15 09:15:18 INFO: Insert extra monitor vertices took 0:00:00.000015
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Partitioner report skipped as cfg Reports:write_partitioner_reports is False
# Placing Vertices
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Application Placer took 0:00:00.005875
# 2025-12-15 09:15:18 INFO: Placements with application graph report skipped as cfg Reports:write_application_graph_placer_report is False
# 2025-12-15 09:15:18 INFO: Json placements skipped as cfg Reports:write_json_placements is False
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: System multicast routing generator took 0:00:00.003697
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Application Router took 0:00:00.004381
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Basic tag allocator took 0:00:00.029215
# 2025-12-15 09:15:18 INFO: Tag allocator report skipped as cfg Reports:write_tag_allocation_reports is False
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Zoned routing info allocator took 0:00:00.006700
# 2025-12-15 09:15:18 INFO: Router info report skipped as cfg Reports:write_router_info_report is False
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Merged routing table generator took 0:00:00.002562
# 2025-12-15 09:15:18 INFO: Uncompressed routing table report skipped as cfg Reports:write_uncompressed is False
# 2025-12-15 09:15:18 INFO: Validating Uncompressed routing table skipped as cfg Mapping:validate_routes_uncompressed is False
# 2025-12-15 09:15:18 INFO: Router report skipped as cfg Reports:write_router_reports is False
# 2025-12-15 09:15:18 INFO: Router summary report skipped as cfg Reports:write_router_summary_report is False
# 2025-12-15 09:15:18 INFO: Json routing tables skipped as cfg Reports:write_json_routing_tables is False
# 2025-12-15 09:15:18 INFO: Locate executable start type took 0:00:00.000203
# 2025-12-15 09:15:18 INFO: Buffer manager creator took 0:00:00.002376
# 2025-12-15 09:15:18 INFO: Write Neo Metadata took 0:00:00.014025
# 2025-12-15 09:15:18 INFO: Record vertex labels to database took 0:00:00.002264
# Resetting Routing
# |0%                          50%                         100%|
#  Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# Clearing Multicast Routes
# |0%                          50%                         100%|
#  ============================================================
#
# ============================================================
# 2025-12-15 09:15:18 INFO: Reset routing took 0:00:00.095161
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Graph binary gatherer took 0:00:00.031131
# 2025-12-15 09:15:18 INFO: Pair on chip router compression skipped as Tables already small enough
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: SDRAM outgoing partition allocator took 0:00:00.003383
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Graph data specification writer took 0:00:00.077572
# 2025-12-15 09:15:18 INFO: Control Sync took 0:00:00.000402
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
#
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:18 INFO: Fixed routes took 0:00:00.038790
# Loading data for system vertices using Java
# |0%                          50%                         100%|
#  2025-12-15 09:15:18 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar dse_sys /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/json_files/machine.json /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/ds.sqlite3 /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/jspin.log
# INFO: will manage database at /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/ds.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.233.9:17893) for /172.20.0.5
# INFO: total retries used: 0
# ============================================================
# 2025-12-15 09:15:20 INFO: Load system data specification took 0:00:01.693080
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:20 INFO: Load executable system Images took 0:00:00.330953
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:20 INFO: Tags Loader took 0:00:00.012003
# Loading data for Application vertices using Java
# |0%                          50%                         100%|
#  ==============================2025-12-15 09:15:20 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar dse_app /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/json_files/machine.json /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/ds.sqlite3 /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/jspin.log
# INFO: will manage database at /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/ds.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.233.9:17893) for /172.20.0.5
# INFO: total retries used: 0
# ==============================
# 2025-12-15 09:15:22 INFO: Load Application data specification took 0:00:01.381198
# preparing to expand neuron data
# |0%                          50%                         100%|
#  ============================================================
#
# Expanding Neuron Data
# |0%                          50%                         100%|
#  ============================================================
#
# Getting initial values
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:23 INFO: Neuron expander took 0:00:00.996036
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
#
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
# Reading generated connections
# |0%                          50%                         100%|
#  ============================================================
#
# 2025-12-15 09:15:24 INFO: Synapse expander took 0:00:01.086949
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:24 INFO: Finish connection holders took 0:00:00.008556
# Loading routing data onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:24 INFO: Routing table loader took 0:00:00.004072
# 2025-12-15 09:15:24 INFO: Bitfield compressor report skipped as cfg Reports:write_bit_field_compressor_report is False
# 2025-12-15 09:15:24 INFO: Tags from machine report skipped as cfg Reports:write_tag_allocation_reports is False
# 2025-12-15 09:15:24 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# 2025-12-15 09:15:24 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# 2025-12-15 09:15:24 INFO: Compressor report skipped as No reports need compressed routing tables
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:25 INFO: Load executable app images took 0:00:00.615007
# 2025-12-15 09:15:25 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# 2025-12-15 09:15:25 INFO: Running for 1 steps for a total of 1000.0ms
# 2025-12-15 09:15:25 INFO: Run 1 of 1
# 2025-12-15 09:15:25 INFO: Sdram usage per chip report skipped as cfg Reports:write_sdram_usage_report_per_chip is False
# 2025-12-15 09:15:25 INFO: Drift report skipped as cfg Reports:write_drift_report_start is False
# 2025-12-15 09:15:25 INFO: Creating live event connection database in /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/input_output_database.sqlite3
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:25 INFO: Create database interface took 0:00:00.034856
# 2025-12-15 09:15:25 INFO: ** Notifying external sources that the database is ready for reading **
# 2025-12-15 09:15:25 INFO: Create notification protocol took 0:00:00.000429
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:25 INFO: Runtime Update took 0:00:00.038512
# 2025-12-15 09:15:25 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# 2025-12-15 09:15:25 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2025-12-15 09:15:25 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2025-12-15 09:15:25 INFO: Application started; waiting 1.1s for it to stop
# 2025-12-15 09:15:26 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2025-12-15 09:15:26 INFO: Application runner took 0:00:01.233592
# 2025-12-15 09:15:26 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# 2025-12-15 09:15:26 INFO: Clear Router Diagnostic Counters took 0:00:00.054565
# 2025-12-15 09:15:26 INFO: Extract IO buff skipped as cfg Reports:extract_iobuf is False
# 2025-12-15 09:15:26 INFO: Starting buffer extraction using Java
# 2025-12-15 09:15:26 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar gather /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/json_files/java_placements.json /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/json_files/machine.json /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/data.sqlite3 /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/jspin.log
# INFO: will manage database at /home/jovyan/CNT-2025/notebooks/intro/reports/2025-12-15-09-14-52-226680/run_1/data.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.233.9:17893) for /172.20.0.5
# INFO: discovering regions to download
# INFO: found 29 regions to download
# INFO: switching multicast routing on board at X:0 Y:0 to system mode
# INFO: will switch 43 cores
# INFO: switching board at X:0 Y:0 (43 monitor cores) to non-drop mode (saved status: flags:1,timeout:3609.0225563909776 ns,emergencyTimeout:0.0 ns,drops:0)
# INFO: launching 1 parallel high-speed download tasks
# INFO: processing fast downloads for X:0 Y:0
# INFO: switching board at X:0 Y:0 to standard mode
# INFO: switching multicast routing on board at X:0 Y:0 to standard mode
# INFO: total misses: 0
# INFO: total retries used: 0
# INFO: waiting for database usage to complete
# INFO: total of 29 database writes done
# 2025-12-15 09:15:30 INFO: Buffer extractor took 0:00:04.351722
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2025-12-15 09:15:30 INFO: Clear IO buffer took 0:00:00.006986
# 2025-12-15 09:15:30 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# 2025-12-15 09:15:30 INFO: Graph provenance gatherer skipped as cfg Reports:read_graph_provenance_data is False
# 2025-12-15 09:15:30 INFO: Placements provenance gatherer skipped as cfg Reports:read_placements_provenance_data is False
# 2025-12-15 09:15:30 INFO: Profile data gatherer skipped as cfg Reports:read_profile_data is False
# 2025-12-15 09:15:30 INFO: Energy report skipped as cfg Reports:write_energy_report is False
# 2025-12-15 09:15:30 INFO: Redundant packet count report skipped as cfg Reports:write_redundant_packet_count_report is False
# 2025-12-15 09:15:30 INFO: Drift report skipped as cfg Reports:write_drift_report_end is False
# 2025-12-15 09:15:30 INFO: Control Sync took 0:00:00.000436

# %%
print(toc)
# Out:
# 38.57609939575195

# %% [markdown]
# # step9: save results

# %%
stateVars = {}
for pop in pops.keys():
    for recording in ['v', 'gsyn_inh', 'gsyn_exc', 'spikes']:
        pops[pop].write_data(f'{saveName}-{recording}.pkl')
        stateVars[pop]=pops[pop].get_data()

# %% [markdown]
# # step10: recover results

# %%
stateVars.keys()
results = pu.recover_results(stateVars)
results.keys()
# Out:
# exc
# gsyn_exc
# gsyn_inh
# v
# inh
# gsyn_exc
# gsyn_inh
# v
# thalamus
# dict_keys([('exc', 'gsyn_exc'), ('exc', 'gsyn_inh'), ('exc', 'v'), ('exc', 'spikes'), ('inh', 'gsyn_exc'), ('inh', 'gsyn_inh'), ('inh', 'v'), ('inh', 'spikes'), ('thalamus', 'spikes')])

# %% [markdown]
# # step11: postprocessing (looking at the results)

# %%
from pyNN.utility.plotting import Figure, Panel

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(stateVars['exc'].segments[0].spiketrains, 
          xlabel="Time/ms", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: excitatory cells spikes")

# %%
### from pyNN.utility.plotting import Figure, Panel

Figure(
    # raster plot of the presynaptic neuron spike times
    Panel(stateVars['exc'].segments[0].spiketrains, xlabel="Time (ms)", xticks=True,
          yticks=True, markersize=0.2, xlim=(0, tstop)),
    title="Vogels-Abbott benchmark: inhibitory cells spikes")

# %%
# classic matplotlib rasterplot function

fig, ax = plt.subplots(2,1, sharex=True, figsize=(9,5))
p0=ax[0].eventplot(results['exc', 'spikes'], color='green')
p1=ax[1].eventplot(results['inh', 'spikes'], color='red')
[ax[i].set_xlabel('Time (ms)', fontsize=14) for i in [0,1]]
[ax[i].set_ylabel(feat, fontsize=14) for i, feat in enumerate(['Excitatory cells', 'Inhibitory cells'])]
# Out:
# [Text(0, 0.5, 'Excitatory cells'), Text(0, 0.5, 'Inhibitory cells')]

# %%
# check spikes

spike_rate = {
    'exc': pops['exc'].get_spike_counts(),
    'inh': pops['inh'].get_spike_counts()
}

idx=50
pop = 'exc'
print(pop + ' cell ' + str(idx) + ' :', spike_rate[pop][idx], 'spikes/' + str(tstop) + 'ms')
# Out:
# exc cell 50 : 6 spikes/1000ms

# %%
# check conductances and membrane voltage potentials

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,3,figsize=(11,4), sharey=True, sharex=False)
ax = ax.flatten()
p=ax[0].hist(np.asarray(results['exc', 'v']).ravel(), 100, label='exc', log=False)
p=ax[1].hist(np.asarray(results['exc', 'gsyn_exc']).ravel(), 100, label='exc')
p=ax[2].hist(np.asarray(results['exc', 'gsyn_inh']).ravel(), 100, label='exc')

p=ax[0].hist(np.asarray(results['inh', 'v']).ravel(), 100, label='inh')
p=ax[1].hist(np.asarray(results['inh', 'gsyn_exc']).ravel(), 100, label='inh')
p=ax[2].hist(np.asarray(results['inh', 'gsyn_inh']).ravel(), 100, label='inh')

ax[0].set_xlim(-90,-40)
ax[1].set_xlim(0,0.2)
ax[2].set_xlim(0,0.5)

[ax[i].legend() for i in [0,1,2]]

[ax[i].set_ylabel('populations', fontsize=14) for i in [0,1,2]]
[ax[idx].set_xlabel(feat, fontsize=14) for idx, feat in enumerate(['membrane potential [mV]', 'gsyn_exc [uS]', 'gsyn_inh [uS]'])]
# Out:
# [Text(0.5, 0, 'membrane potential [mV]'),
#  Text(0.5, 0, 'gsyn_exc [uS]'),
#  Text(0.5, 0, 'gsyn_inh [uS]')]

# %% [markdown]
# # step12: close simulation

# %%
# if you run it, you cannot reload some cells, but it is needed to restart the overall simulation

#sim.end()

# %% [markdown]
# ## Task 1: on the self sustained acitivity conditions
#
# - in the image below, the panel a) shows the sustained activity conditions of the network. <br>
#   Try different set of weights combinations for discovering different functional network configurations

# %% [markdown]
# <img src="../extra/VA_EXC_BALANCE.png">

# %% [markdown]
# - image taken from Vogels & Abbott (J. Neurosci, 2005) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6725859/,

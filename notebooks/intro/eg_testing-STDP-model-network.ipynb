# %% [markdown]
# # STDP model network
#
# http://www.scholarpedia.org/article/Spike-timing_dependent_plasticity
#
# STDP can be seen as a spike-based formulation of a Hebbian learning rule.

# %% [markdown]
# Two thalamic inputs are sent to two cells (one for each) such that there's a small time gap between the two inputs.
#
# Two cells are excitatory and the synapse from the first cells to the second is modelled with STDP.

# %%
# fileName

# run only with sPyNNaker

fileName = 'eg_testing-STDP-model-network'
savePath = f'../outputs/'
saveName = savePath+fileName
saveName
# Out:
# '../outputs/eg_testing-STDP-model-network'

# %%
try:
    import pyNN.spiNNaker as sim
except ModuleNotFoundError:
    import pyNN.brian2 as sim
    
from pyNN import space 
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pickle
import time
import datetime
import json
import warnings
warnings.filterwarnings('ignore')
import python_utils as pu

# %matplotlib inline

savePath = f'../outputs/' # remember to create the folder if not already present (mkdir ./notebooks/outputs)
dt_string = datetime.datetime.today().isoformat() # ISO8601 ! :-)
tag = dt_string 
saveName = f'{savePath}{fileName}-{tag}'
print(saveName)
PARS={}
# Out:
# /home/jovyan/work/CNT-2025/notebooks/intro/python_utils.py:25: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF
# ../outputs/eg_testing-STDP-model-network-2026-04-21T10:46:30.314948

# %%
# simulation settings

sim.setup(
        timestep=1, # [ms]
        min_delay=1, # [ms]
        max_delay=100) # [ms]

simtime = 150 # [ms+]
# Out:
# max_delay is not supported by sPyNNaker so will be ignored
# 2026-04-21 10:46:30 INFO: Read configs files: /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_utilities/spinn_utilities.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_machine/spinn_machine.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/pacman/pacman.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinnman/spinnman.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/jovyan/.spynnaker.cfg
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: As mode is Production running all reports and keeping files is turned off unless specifically asked for in cfg
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Will search these locations for binaries: /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spynnaker/pyNN/model_binaries
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 WARNING: /home/jovyan/work/CNT-2025/notebooks/intro/reports has 27 old reports that have not been closed
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Setting hardware timestep as 1000 microseconds based on simulation time step of 1000 and timescale factor of 1.0

# %% [markdown]
# ## make the network

# %%
# define make_pop

pops = {}

pops['pre'] = sim.Population(
                        1, # one cell in each cell model
                        sim.IF_cond_exp(),
                        #cellparams=sim.IF_curr_exp.default_initial_values, # std pars used
                        structure = space.Line(dx=1.0, x0=0.0, y=0.0, z=0.0),
                        label='pre',
                        )
                        
pops['post'] = sim.Population(
                        1, # one cell in each cell model
                        sim.IF_cond_exp(),
                        #cellparams=sim.IF_curr_exp.default_initial_values, # std pars used
                        structure = space.Line(dx=1.0, x0=0.0, y=0.0, z=0.0),
                        label='post',
                        )

pops['pre'].record(['spikes', 'v', 'gsyn_exc', 'gsyn_inh'])
pops['post'].record(['spikes', 'v', 'gsyn_exc', 'gsyn_inh'])

pops.keys()
# Out:
# dict_keys(['pre', 'post'])

# %% [markdown]
# ## make the thalamic input stimulus

# %%
pops['thalamus-pre'] = sim.Population(1, 
                            sim.SpikeSourceArray([30, 40, 50, 60, ]),
                            structure = space.Line(dx=1.0, x0=0.0, y=0.0, z=0.0),
                            )    

pops['thalamus-post'] = sim.Population(1, 
                             sim.SpikeSourceArray([32, 42, 52, 62, ]),
                             structure = space.Line(dx=1.0, x0=0.0, y=0.0, z=0.0))

pops['thalamus-post'].record('spikes')
pops['thalamus-pre'].record('spikes')


pops.keys()
# Out:
# dict_keys(['pre', 'post', 'thalamus-pre', 'thalamus-post'])

# %% [markdown]
# ## make learning rule between pre and post syn cells

# %%
timing = sim.SpikePairRule(tau_plus=10.0, 
                           tau_minus=1.0, 
                           A_plus=0.5, 
                           A_minus=0.5)

weight = sim.AdditiveWeightDependence(w_max=5, w_min=0.0) # range of learnig 

starting_weight = 0 #0.1 # uS
projs = {}
projs['pre', 'post'] = sim.Projection(pops['pre'], pops['post'], 
                                      sim.OneToOneConnector(), 
                                      sim.STDPMechanism(
                                          timing_dependence=timing, 
                                          weight_dependence=weight, 
                                          weight=starting_weight, 
                                          delay=5.0))

projs.keys()
# Out:
# dict_keys([('pre', 'post')])

# %% [markdown]
# ## make the thalamic - pops projections

# %%
projs['thalamus-pre', 'pre'] = sim.Projection(
                                    pops['thalamus-pre'],
                                    pops['pre'],
                                    sim.OneToOneConnector(),
                                    synapse_type=sim.StaticSynapse(weight=5),#, delay=None),
                                    receptor_type = 'excitatory',
                                    space = space.Space(axes = 'x'),
                                    label=None,
                                )


projs['thalamus-post', 'post'] = sim.Projection(
                                    pops['thalamus-post'],
                                    pops['post'],
                                    sim.OneToOneConnector(),
                                    synapse_type=sim.StaticSynapse(weight=5),#, delay=1.0),
                                    receptor_type = 'excitatory',
                                    space = space.Space(axes = 'x'),
                                    label=None,
                                )



projs.keys()
# Out:
# dict_keys([('pre', 'post'), ('thalamus-pre', 'pre'), ('thalamus-post', 'post')])

# %% [markdown]
# ## run the simulation

# %%
# simulation run

tic = time.time()
sim.run(simtime)
toc = time.time() - tic
print(toc)
# Out:
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Starting execution process
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Simulating for 150 1.0 ms timesteps using a hardware timestep of 1000 us
# openjdk version "21.0.9" 2025-10-21
# OpenJDK Runtime Environment (build 21.0.9+10-Ubuntu-124.04)
# OpenJDK 64-Bit Server VM (build 21.0.9+10-Ubuntu-124.04, mixed mode, sharing)
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: SpYNNakerNeuronGraphNetworkSpecificationReport skipped as cfg Reports:write_network_graph is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Network Specification report skipped as cfg Reports:write_network_specification_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Splitter reset took 0:00:00.000027
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Spynnaker splitter selector took 0:00:00.007756
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: DelaySupportAdder took 0:00:00.033532
# Partitioning Graph
# |0%                          50%                         100%|
#  /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 WARNING: The cfg has no version. This is deprecated! Please add a version
# ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Splitter partitioner took 0:00:00.024774
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: 0.02 Boards Required for 1 chips
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:30 INFO: Requesting job with 1 boards
# Created spalloc job 143987
# 2026-04-21 10:46:30 INFO: Created spalloc job 143987
# Job has been queued by the spalloc server.
# 2026-04-21 10:46:31 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2026-04-21 10:46:31 INFO: Waiting for board power commands to complete.
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:41 INFO: Creating transceiver for 10.11.242.105
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:41 INFO: Working out if machine is booted
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:45 INFO: Attempting to boot machine
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Found board with version [Version: SC&MP 4.0.0 at SpiNNaker:0:0:0 (built Fri Nov 17 09:35:48 2023)]
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Machine communication successful
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: 10.11.242.105
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Transceiver by Spalloc Old took 0:00:22.605423
# Reading details from 48 chips
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Detected Machine on 10.11.242.105 with 48 Chips, 854 cores and 120.0 links. Chips have sdram of 123469792 bytes, router table of size 1023, between 17 and 18 cores and between 3 and 6 links.
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Json machine skipped as cfg Reports:write_json_machine is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Board chip report skipped as cfg Reports:write_board_chip_report is False
# Adding commands
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Command Sender Adder took 0:00:00.005402
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Split Live Gather Vertices took 0:00:00.000035
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Insert chip power monitors skipped as cfg Reports:write_energy_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Insert extra monitor vertices took 0:00:00.000033
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Partitioner report skipped as cfg Reports:write_partitioner_reports is False
# Placing Vertices
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Application Placer took 0:00:00.011244
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Placements with application graph report skipped as cfg Reports:write_application_graph_placer_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Json placements skipped as cfg Reports:write_json_placements is False
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: System multicast routing generator took 0:00:00.007841
# Routing
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Application Router took 0:00:00.005615
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Basic tag allocator took 0:00:00.038033
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Tag allocator report skipped as cfg Reports:write_tag_allocation_reports is False
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Zoned routing info allocator took 0:00:00.009243
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Router info report skipped as cfg Reports:write_router_info_report is False
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Merged routing table generator took 0:00:00.003153
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Uncompressed routing table report skipped as cfg Reports:write_uncompressed is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Validating Uncompressed routing table skipped as cfg Mapping:validate_routes_uncompressed is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Router report skipped as cfg Reports:write_router_reports is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Router summary report skipped as cfg Reports:write_router_summary_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Json routing tables skipped as cfg Reports:write_json_routing_tables is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Locate executable start type took 0:00:00.000477
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Buffer manager creator took 0:00:00.004902
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spynnaker/pyNN/utilities/neo_buffer_database.py:146: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Write Neo Metadata took 0:00:00.053602
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:53 INFO: Record vertex labels to database took 0:00:00.004855
# Resetting Routing
# |0%                          50%                         100%|
#  Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# Clearing Multicast Routes
# |0%                          50%                         100%|
#  ============================================================
#
# ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Reset routing took 0:00:00.152480
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Graph binary gatherer took 0:00:00.040682
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Pair on chip router compression skipped as Tables already small enough
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: SDRAM outgoing partition allocator took 0:00:00.005157
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Graph data specification writer took 0:00:00.110202
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Control Sync took 0:00:00.000735
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
#
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Fixed routes took 0:00:00.063089
# Loading data for system vertices using Java
# |0%                          50%                         100%|
#  /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:54 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar dse_sys /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/json_files/machine.json /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/ds.sqlite3 /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/jspin.log
# INFO: will manage database at /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/ds.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.242.105:17893) for /172.20.0.10
# INFO: total retries used: 0
# ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:57 INFO: Load system data specification took 0:00:02.950272
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:57 INFO: Load executable system Images took 0:00:00.272179
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:57 INFO: Tags Loader took 0:00:00.018223
# Loading data for Application vertices using Java
# |0%                          50%                         100%|
#  ==============================/home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:57 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar dse_app /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/json_files/machine.json /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/ds.sqlite3 /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/jspin.log
# INFO: will manage database at /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/ds.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.242.105:17893) for /172.20.0.10
# INFO: total retries used: 0
# ==============================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:46:59 INFO: Load Application data specification took 0:00:02
# preparing to expand neuron data
# |0%                          50%                         100%|
#  ============================================================
#
# Expanding Neuron Data
# |0%                          50%                         100%|
#  ============================================================
#
# Getting initial values
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:00 INFO: Neuron expander took 0:00:00.661002
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
#
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
# Reading generated connections
# |0%                          50%                         100%|
#  ============================================================
#
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Synapse expander took 0:00:00.754053
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Finish connection holders took 0:00:00.004293
# Loading routing data onto the machine
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Routing table loader took 0:00:00.004853
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Bitfield compressor report skipped as cfg Reports:write_bit_field_compressor_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Tags from machine report skipped as cfg Reports:write_tag_allocation_reports is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Compressor report skipped as No reports need compressed routing tables
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Load executable app images took 0:00:00.730346
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Running for 1 steps for a total of 150.0ms
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Run 1 of 1
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Sdram usage per chip report skipped as cfg Reports:write_sdram_usage_report_per_chip is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Drift report skipped as cfg Reports:write_drift_report_start is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Creating live event connection database in /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/input_output_database.sqlite3
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Create database interface took 0:00:00.037108
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Create notification protocol took 0:00:00.000682
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  2026-04-21 10:47:01 INFO: ** Notifying external sources that the database is ready for reading **
# ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: Runtime Update took 0:00:00.028960
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:01 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Application started; waiting 0.25s for it to stop
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Application runner took 0:00:00.393125
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# Clearing router diagnostic counters
# |0%                          50%                         100%|
#  ============================================================
#
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Clear Router Diagnostic Counters took 0:00:00.035101
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Extract IO buff skipped as cfg Reports:extract_iobuf is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Starting buffer extraction using Java
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:02 INFO: Calling Java with: java -jar /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/JavaSpiNNaker/SpiNNaker-front-end/target/spinnaker-exe.jar gather /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/json_files/java_placements.json /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/json_files/machine.json /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/data.sqlite3 /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/jspin.log
# INFO: will manage database at /home/jovyan/work/CNT-2025/notebooks/intro/reports/2026-04-21-10-46-30-385316/run_1/data.sqlite3
# INFO: registering connection SCPConnection(X:0 Y:0 <--> /10.11.242.105:17893) for /172.20.0.10
# INFO: discovering regions to download
# INFO: found 10 regions to download
# INFO: switching multicast routing on board at X:0 Y:0 to system mode
# INFO: will switch 48 cores
# INFO: switching board at X:0 Y:0 (48 monitor cores) to non-drop mode (saved status: flags:1,timeout:3609.0225563909776 ns,emergencyTimeout:0.0 ns,drops:0)
# INFO: launching 1 parallel high-speed download tasks
# INFO: processing fast downloads for X:0 Y:0
# INFO: switching board at X:0 Y:0 to standard mode
# INFO: switching multicast routing on board at X:0 Y:0 to standard mode
# INFO: total misses: 0
# INFO: total retries used: 0
# INFO: waiting for database usage to complete
# INFO: total of 10 database writes done
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Buffer extractor took 0:00:02.336051
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Clear IO buffer took 0:00:00.005392
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Router provenance gatherer skipped as cfg Reports:read_router_provenance_data is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Graph provenance gatherer skipped as cfg Reports:read_graph_provenance_data is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Placements provenance gatherer skipped as cfg Reports:read_placements_provenance_data is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Profile data gatherer skipped as cfg Reports:read_profile_data is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Energy report skipped as cfg Reports:write_energy_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Redundant packet count report skipped as cfg Reports:write_redundant_packet_count_report is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Drift report skipped as cfg Reports:write_drift_report_end is False
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:04 INFO: Control Sync took 0:00:00.000682
# 34.297099351882935

# %% [markdown]
# ## save and get results

# %%
stateVars = {}
for pop in pops.keys():
    for recording in ['v', 'gsyn_inh', 'gsyn_exc', 'spikes']:
        pops[pop].write_data(f'{saveName}-{recording}.pkl')
        stateVars[pop]=pops[pop].get_data()

stateVars.keys()
results = pu.recover_results(stateVars)
results.keys()
# Out:
# pre
# gsyn_exc
# gsyn_inh
# v
# post
# gsyn_exc
# gsyn_inh
# v
# thalamus-pre
# thalamus-post
# dict_keys([('pre', 'gsyn_exc'), ('pre', 'gsyn_inh'), ('pre', 'v'), ('pre', 'spikes'), ('post', 'gsyn_exc'), ('post', 'gsyn_inh'), ('post', 'v'), ('post', 'spikes'), ('thalamus-pre', 'spikes'), ('thalamus-post', 'spikes')])

# %% [markdown]
# ## check the spikes

# %%
fig, axes = plt.subplots(1,1, figsize=(9,7))
fig.tight_layout(pad=5)
axes_list = fig.axes


axes_list[0].eventplot(results['thalamus-pre', 'spikes'], label='thalamus-pre', color='r')
axes_list[0].eventplot(results['thalamus-post', 'spikes'], label='thalamus-post', color='b')
axes_list[0].set_title('thalamic spikes')
axes_list[0].set_xlabel('[ms]')
axes_list[0].set_ylabel('cells ID')
axes_list[0].set_xlim(0,simtime)
#axes_list[0].set_ylim(0,2)
axes_list[0].legend()


fig, axes = plt.subplots(1,1, figsize=(13, 9))
fig.tight_layout(pad=5)
axes_list = fig.axes
axes_list[0].eventplot(results['pre', 'spikes'], label='pre', color='k')
axes_list[0].eventplot(results['post', 'spikes'], label='post', color='g')
axes_list[0].set_xlabel('[ms]')
axes_list[0].set_title('cells spikes')
axes_list[0].set_xlim(0,simtime)
axes_list[0].legend()
axes_list[0].set_xlabel('[ms]')
axes_list[0].set_ylabel('cells ID')
# Out:
# Text(125.22222222222221, 0.5, 'cells ID')

# %% [markdown]
# ## check the voltage signature

# %%
fig, axes = plt.subplots(2, 1, sharex=True, sharey=False)#, figsize=(11,7))
fig.tight_layout(pad=3)
fig.suptitle('voltage signature in pre and post synaptic cells')

axes_list = fig.axes
for idx, syn in enumerate(['pre', 'post']):
    axes_list[idx].plot(results[syn, 'v'], label=str(syn))
    axes_list[idx].legend()

# %%
fig, axes = plt.subplots(2, 1, sharex=True, sharey=False)#, figsize=(11,7))
fig.tight_layout(pad=3)
fig.suptitle('gsyn_exc signature in pre and post synaptic cells')

axes_list = fig.axes
idx = 0
for idx, syn in enumerate(['pre', 'post']):
    axes_list[idx].plot(results[syn, 'gsyn_exc'], label=str(syn))
    axes_list[idx].legend()

# %%
fig, axes = plt.subplots(2, 1, sharex=True, sharey=False)#, figsize=(11,7))
fig.tight_layout(pad=3)
fig.suptitle('gsyn_inh signature in pre and post synaptic cells')

axes_list = fig.axes
idx = 0
for idx, syn in enumerate(['pre', 'post']):
    axes_list[idx].plot(results[syn, 'gsyn_inh'], label=str(syn))
    axes_list[idx].legend()

# %% [markdown]
# ## check the STDP between pre and post cells

# %%
projs.keys()
#projs['pre', 'post'].get(['source', 'target', 'weight', 'delay'], "list")
print('starting weight pre stdp: ', starting_weight, ' [uS]')
print('final weight after stdp: ', projs['pre', 'post'].get('weight', format='list'), ' [uS]')
# Out:
# Getting synaptic data between pre and post
# |0%                          50%                         100%|
#  ============================================================
# starting weight pre stdp:  0  [uS]
# final weight after stdp:  ([np.uint32(0), np.uint32(0), np.float64(4.421875)],)  [uS]

# %%
# the weight between pre and post neuron was set to zero before the learning, now it's ..

# %% [markdown]
# ## end the simulations

# %%
sim.end()
# Out:
# /home/jovyan/.kernels/sPyNNaker_7.4.1/lib/python3.13/site-packages/spinn_front_end_common/interface/provenance/global_provenance.py:189: DeprecationWarning: The default datetime adapter is deprecated as of Python 3.12; see the sqlite3 documentation for suggested replacement recipes
#   self.cursor().execute(
# 2026-04-21 10:47:06 INFO: Cleanup reports folder based on cfg took 0:00:00.000967

# %% [markdown]
# # task1: on thalamus input spike times
# - test different interspike timing <br>
#   e.g., <br>
#     a=np.arange(0,100,10) for the thalamus-pre <br>
#     a+15 for the thalamus post <br>
#
# - test only one spike source eliciting the pre synaptic cell<br>

# %% [markdown]
# # task2: on STDP mechanism
# - try to change the parameter inside the SpikePairRule
# - create the STDP "weights as function of delta time" plot
# - check: http://www.scholarpedia.org/article/Spike-timing_dependent_plasticity

# %%
# start from this snap

SPIKES={}
for feat in ['pre', 'post']:
    VAR=results[feat, 'spikes']
    for k in range(len(VAR)):
        SPIKES[feat]=[]
        SPIKES[feat].append(np.array(list(VAR[k])).T,)

post=SPIKES['post'][0][0:len(SPIKES['pre'][0])],
pre=SPIKES['pre'][0]

x=np.sort(post-pre)
xTh=np.linspace(-25, 25, 100)

A_plus=0.5
A_minus=0.5
tau_plus=10
tau_minus=1

# equations from http://www.scholarpedia.org/article/Spike-timing_dependent_plasticity
W_x_plus = A_plus*np.exp(-x[x>0]/tau_plus)
W_x_minus = - A_minus*np.exp(x[x<0]/tau_minus)

W_x_plus_th = A_plus*np.exp(-xTh[xTh>0]/tau_plus)
W_x_minus_th = - A_minus*np.exp(xTh[xTh<0]/tau_minus)

plt.figure(figsize=(9, 5))
plt.plot(x[0], np.array(list(W_x_minus)+list(W_x_plus)), ':d', c='r', label='weight changes')
plt.plot(xTh, np.array(list(W_x_minus_th)+list(W_x_plus_th)), ':+', label='weight changes theory')

#plt.axhline(y=0)
plt.axvline(x=0)
plt.xlabel('delta times: POST minus PRE spike times [ms]')
plt.ylabel('actual weights:  [uS]')
plt.axhline(y=starting_weight, color='k', alpha=.1, label='starting weight')
plt.legend()
plt.savefig(f'{saveName}.jpeg', dpi=70, bbox_inches='tight', facecolor='white')

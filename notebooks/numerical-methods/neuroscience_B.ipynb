# %%
import warnings
warnings.filterwarnings('ignore')

import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from brian2 import prefs
prefs.codegen.target = "numpy"

from brian2 import *

# %% [markdown]
# # solvers in brian2

# %% [markdown]
# - **`exponential_euler`**: This method is a variant of the Euler method for solving ordinary differential equations (ODEs). It's specifically designed for linear ODEs and provides exact solutions when the ODE is linear.
#
# - **`euler`**: The Euler method is a first-order numerical procedure for solving ODEs with a given initial value. It's named after Leonhard Euler who introduced it.
#
# - **`rk2`**: The RK2 method, also known as Heun's method, is a simple, explicit method of the Runge-Kutta type for the numerical solution of ODEs.
#
# - **`rk4`**: The RK4 method is a fourth-order method for solving ODEs. It's the most commonly used method of the Runge-Kutta family.
#
# - **`heun`**: Heun's method is an improved version of the Euler method which is second-order accurate. It's also known as the Euler predictor-corrector method.
#
# - **`milstein`**: The Milstein method is used for the numerical solution of stochastic differential equations (SDEs). It's a modification of the Euler–Maruyama method which includes a second-order term.

# %% [markdown]
# # the LIF model

# %%
def LIF(solver, h, t0, t1, t_sim):

    start_time = time.time()
    
    # Definisci il tempo di simulazione
    t_sim = t_sim*ms
    
    # Definisci il passo temporale
    dt = h*ms
    
    # Crea un array con i valori della corrente
    I_values = zeros(int(t_sim/dt))*nA
    t0 = t0
    t1 = t1
    I_values[int(t0*ms/dt):int((t1*ms/dt))] = 10*nA  # corrente di 1 nA 
    
    # Crea un TimedArray con i valori della corrente
    I_ext = TimedArray(I_values, dt=dt)
    
    # Parametri del modello
    C = 1*nF  # Capacità della membrana
    R_m = 10*Mohm  # Resistenza della membrana
    V_rest = -65*mV  # Potenziale di riposo
    V_reset = -80*mV
    tau_m = R_m*C  # Costante di tempo della membrana
    
    # Modello Integrate-and-Fire
    eqs = '''
    dV/dt = (-(V - V_rest) + I_ext(t)*R_m) / tau_m : volt (unless refractory)
    '''
    neuron = NeuronGroup(1, eqs, threshold='V>-50*mV', reset='V=V_reset', refractory=5*ms, method=solver)
    neuron.V = V_rest
    monitor = StateMonitor(neuron, 'V', record=True)
    net = Network(neuron, monitor)
    
    # Esecuzione della simulazione
    net.run(t_sim)
    times = monitor.t/ms
    potential = monitor.V[0]/mV


    finish_time = time.time()

    ct = finish_time - start_time
    
    return ct, times, potential

# %% [markdown]
# # one spike

# %%
h = 1
k = 1
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    ct, times, potential = LIF(solver, h=h, t0=250, t1=250+k, t_sim=500)
    plt.plot(times, potential, ':', label=solver)
    plt.legend()

# %%
h = 1
CT = []
k = 1
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    
    for h_ in np.linspace(1e-3, 1, 25):
        ct, times, potential = LIF(solver, h=h, t0=250, t1=250+k, t_sim=500)
        CT.append([ct, solver, h_*1e-3])

# %%
data=pd.DataFrame(data=CT, columns=['ct', 'solver', 'h'])
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    sns.regplot(data=data[data['solver']==solver], x='h', y='ct', order=1, label=solver, scatter=False)
plt.legend()

# %% [markdown]
# ## two spikes

# %%
h = 1
k = 10
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    ct, times, potential = LIF(solver, h=h, t0=250, t1=251+k, t_sim=500)
    plt.plot(times, potential, ':')
    plt.xlim(200, 300)

# %% [markdown]
# ##

# %%
CT = []
k = 10
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    for h_ in np.linspace(1e-3, 1, 25):
        ct, times, potential = LIF(solver, h=h_, t0=250, t1=250+k, t_sim=500)
        CT.append([ct, solver, h_*1e-3])
# Out:
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 125.875 us (ratio: 1/1.25875) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 167.5 us (ratio: 1/1.675) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 209.125 us (ratio: 1/2.09125) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 250.75 us (ratio: 1/2.5075000000000003) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 292.375 us (ratio: 1/2.9237499999999996) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.334 ms (ratio: 1/3.3400000000000003) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.375625 ms (ratio: 1/3.75625) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.41725 ms (ratio: 1/4.1725) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.458875 ms (ratio: 1/4.58875) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.5005 ms (ratio: 1/5.005000000000001) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.542125 ms (ratio: 1/5.421250000000001) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.58375 ms (ratio: 1/5.8374999999999995) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.625375 ms (ratio: 1/6.25375) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.667 ms (ratio: 1/6.67) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.708625 ms (ratio: 1/7.086250000000001) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.75025 ms (ratio: 1/7.5025) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.791875 ms (ratio: 1/7.91875) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.8335 ms (ratio: 1/8.335) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.875125 ms (ratio: 1/8.75125) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.91675 ms (ratio: 1/9.1675) → time grids not aligned [brian2.input.timedarray]
# WARNING    Group uses a dt of 100. us while TimedArray uses dt of 0.958375 ms (ratio: 1/9.58375) → time grids not aligned [brian2.input.timedarray]

# %%
data=pd.DataFrame(data=CT, columns=['ct', 'solver', 'h'])

for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    sns.regplot(data=data[data['solver']==solver], x='h', y='ct', order=1, label=solver, scatter=False)
plt.legend()

# %% [markdown]
# # three spikes

# %%
h = 1
k = 20
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    ct, times, potential = LIF(solver, h=h, t0=250, t1=250+k, t_sim=500)
    plt.plot(times, potential, ':')
    plt.xlim(200, 300)

# %%
CT = []
k = 20

for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    for h_ in np.linspace(1e-3, 1, 25):
        ct, times, potential = LIF(solver, h=h_, t0=250, t1=250+k, t_sim=500)
        CT.append([ct, solver, h_*1e-3])

# %%
data=pd.DataFrame(data=CT, columns=['ct', 'solver', 'h'])
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    sns.regplot(data=data[data['solver']==solver], x='h', y='ct', order=1, label=solver, scatter=False)
plt.legend()

# %% [markdown]
# ## n spikes

# %%
h = 1
k = 100
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    ct, times, potential = LIF(solver, h=h, t0=250, t1=250+k, t_sim=500)
    plt.plot(times, potential, ':')
    plt.xlim(200, 400)

# %%
CT = []
k = 100

for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    for h_ in np.linspace(1e-3, 1, 25):
        ct, times, potential = LIF(solver, h=h_, t0=250, t1=250+k, t_sim=500)
        CT.append([ct, solver, h_*1e-3])

# %%
data=pd.DataFrame(data=CT, columns=['ct', 'solver', 'h'])
for solver in ['exponential_euler', 
                'euler', 
                'rk2', 
                'rk4', 
                'heun', 
                'milstein']:
    sns.regplot(data=data[data['solver']==solver], x='h', y='ct', order=1, label=solver, scatter=False)
plt.legend()
